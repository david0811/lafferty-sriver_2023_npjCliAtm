# %%
import numpy as np
import xarray as xr
import intake

# %%
cat = intake.open_esm_datastore(
    "https://cpdataeuwest.blob.core.windows.net/cp-cmip/version1/catalogs/global-downscaled-cmip6.json"
)

# %%
cat_gardsv = cat.search(method="GARD-SV")

# %%
cat_subset = cat.search(
    method="GARD-SV",
    source_id="BCC-CSM2-MR",
    experiment_id=["ssp245", "ssp370", "ssp585"],
    variable_id=["tasmax","tasmin"]
)

# %%
cat_subset.df
# Out:
#    activity_id institution_id    source_id experiment_id member_id timescale  \
# 0  ScenarioMIP            BCC  BCC-CSM2-MR        ssp245  r1i1p1f1       day
# 1  ScenarioMIP            BCC  BCC-CSM2-MR        ssp245  r1i1p1f1       day
# 2  ScenarioMIP            BCC  BCC-CSM2-MR        ssp370  r1i1p1f1       day
# 3  ScenarioMIP            BCC  BCC-CSM2-MR        ssp370  r1i1p1f1       day
# 4  ScenarioMIP            BCC  BCC-CSM2-MR        ssp585  r1i1p1f1       day
# 5  ScenarioMIP            BCC  BCC-CSM2-MR        ssp585  r1i1p1f1       day
#
#   variable_id   method                          downscaled_daily_data_uri  \
# 0      tasmax  GARD-SV  https://cpdataeuwest.blob.core.windows.net/cp-...
# 1      tasmin  GARD-SV  https://cpdataeuwest.blob.core.windows.net/cp-...
# 2      tasmax  GARD-SV  https://cpdataeuwest.blob.core.windows.net/cp-...
# 3      tasmin  GARD-SV  https://cpdataeuwest.blob.core.windows.net/cp-...
# ...

# %%
dsets = cat_subset.to_dataset_dict()
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.timescale.method'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3/3 00:04&lt;00:00]
#     </div>

# %%
dsets[list(dsets.keys())[0]]
# Out:
# <xarray.Dataset>
# Dimensions:    (lat: 721, lon: 1440, member_id: 1, time: 31046)
# Coordinates:
#   * lat        (lat) float32 -90.0 -89.75 -89.5 -89.25 ... 89.25 89.5 89.75 90.0
#   * lon        (lon) float32 -180.0 -179.8 -179.5 -179.2 ... 179.2 179.5 179.8
#   * time       (time) datetime64[ns] 2015-01-01 2015-01-02 ... 2099-12-31
#   * member_id  (member_id) object 'r1i1p1f1'
# Data variables:
#     tasmax     (member_id, time, lat, lon) float32 dask.array<chunksize=(1, 31046, 48, 48), meta=np.ndarray>
#     tasmin     (member_id, time, lat, lon) float32 dask.array<chunksize=(1, 31046, 48, 48), meta=np.ndarray>
# Attributes: (12/26)
#     Conventions:                      CF-1.8
#     activity_id:                      ScenarioMIP
#     cmip6_downscaling_contact:        hello@carbonplan.org
#     cmip6_downscaling_explainer:      https://carbonplan.org/research/cmip6-d...
#     cmip6_downscaling_institution:    CarbonPlan
#     cmip6_downscaling_method:         GARD-SV
# ...

# %%
list(dsets.keys())[0]
# Out:
# 'ScenarioMIP.BCC.BCC-CSM2-MR.ssp370.day.GARD-SV'
